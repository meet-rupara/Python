# %%
# DataTypes In Python 


a = 5    #int 
b =1.234  #float
c =" meet "  #string
d  = True  #boolean 
e = None  #none

print("thr types are : ",a,b,c,d,e)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# thr types are :  5 1.234  meet  True None
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
