# %%
print(" hello ")
# Out:
#  hello

# %%
# Single line comments 

"""" Multi Line comments """

# print("hello world 1  ")
print("hello world 2 ")
# Out:
# hello world 2

# %%
# Taking simple input from the user 

x=input("Enter the value: ");

print("Entered value is : ",x)
# Out:
# Entered value is :  12323123123

# %%
name  = "vs "
full_name =" vs code"
_name = "vs codde ide"
Name = 1234

print(name)
print(full_name)
print(_name)
print(Name)
# Out:
# vs
#  vs code
# vs codde ide
# 1234

# %%
#delete a variable
a=300
print(a)

del a
print(a)
# Out:
# 300
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 print(a)
#       5 del a
# ----> 6 print(a)
#
# NameError: name 'a' is not defined
