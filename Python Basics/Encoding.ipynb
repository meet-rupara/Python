# %%
var = "\u0031\u0030"
print (var)
# Out:
# 10

# %%
a="Hello Python "
b=a.encode("utf-8")
print(b)
c=a.encode('utf-16')
print(c)
# Out:
# b'Hello Python '
# b'\xff\xfeH\x00e\x00l\x00l\x00o\x00 \x00P\x00y\x00t\x00h\x00o\x00n\x00 \x00'

# %%
a="\u20B9 "
print(a)
b=a.encode("utf-8")
print(b)
c=a.encode('utf-16')
print(c)
# Out:
# ₹
# b'\xe2\x82\xb9 '
# b'\xff\xfe\xb9  \x00'
