# %%
#  Functions 

def function_name (str):
    "function doc string"
    print(str)
    # return 0

function_name("hello function")
# Out:
# hello function

# %%
def sum(a,b):
    c=a+b
    return c

result = sum(5,8)
print("Sum is : ",result)
# Out:
# Sum is :  13

# %%
# Lambda function 

result = lambda a,b: a+b
print("The sum is : ",result(5,8))
# Out:
# The sum is :  13
